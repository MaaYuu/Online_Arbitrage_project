# %%
import pandas as pd
from IPython.core.display import HTML
from datetime import datetime

# %%
df = pd.read_csv("../online_arbitrage_files/2021_06_12/etsy.csv", sep=';', usecols=['image_cs', 'image_et'])

# %%
df
# Out:
#                                              image_et  \
# 0   https://i.etsystatic.com/30256314/c/1600/1197/...
# 1   https://i.etsystatic.com/30167768/d/il/b834df/...
# 2   https://i.etsystatic.com/22478503/d/il/ab6c80/...
# 3   https://i.etsystatic.com/30290087/c/2125/1689/...
# 4   https://i.etsystatic.com/18402071/d/il/9eddf0/...
# ..                                                ...
# 84  https://i.etsystatic.com/29233561/d/il/639bfd/...
# 85  https://i.etsystatic.com/22798449/d/il/61978f/...
# 86  https://i.etsystatic.com/18456960/d/il/630a14/...
# 87  https://i.etsystatic.com/9683744/d/il/cc0c91/2...
# 88  https://i.etsystatic.com/9683744/d/il/5d1e1a/2...
#
#                                              image_cs
# 0   https://cdn03.ciceksepeti.com/cicek/kc2546726-...
# 1   https://cdn03.ciceksepeti.com/cicek/kc2546726-...
# 2   https://cdn03.ciceksepeti.com/cicek/kc2546726-...
# 3   https://cdn03.ciceksepeti.com/cicek/kc2546726-...
# ...

# %%
def path_to_image_html(path):
    return '<img src="' + path + '" width="60" >'

# %%
HTML(df.to_html(escape=False, formatters=dict(df=path_to_image_html)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c238e3ab5ed7> in <module>
# ----> 1 HTML(df.to_html(escape=False, formatters=dict(df=path_to_image_html)))
#
# NameError: name 'HTML' is not defined

# %%
HTML(deneme)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>image_et</th>
#       <th>image_cs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://i.etsystatic.com/30256314/c/1600/1197/0/0/il/afb716/3186714459/il_340x270.3186714459_42y4.jpg</td>
#       <td>https://cdn03.ciceksepeti.com/cicek/kc2546726-1/M/mekanizmali-deri-cuzdan-kc2546726-1-bab6c77b39f34d8a971753b66bcc6db8.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>https://i.etsystatic.com/30167768/d/il/b834df/3167234349/il_340x270.3167234349_kgwd.jpg?version=0</td>
#       <td>https://cdn03.ciceksepeti.com/cicek/kc2546726-1/M/mekanizmali-deri-cuzdan-kc2546726-1-bab6c77b39f34d8a971753b66bcc6db8.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>https://i.etsystatic.com/22478503/d/il/ab6c80/3188060047/il_340x270.3188060047_1zqw.jpg?version=0</td>
# ...
